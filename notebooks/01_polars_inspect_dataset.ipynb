# %%
import polars as pl

file_path = "complaint-intelligence-platform/data/raw/complaints.csv"

# Load dataset
df = pl.read_csv(file_path)

print("\nDataset shape:")
print(df.shape)

print("\nColumns in dataset:")
print(df.columns)

print("\nFirst 5 rows:")
print(df.head())
# Out:
# Dataset shape:
# (13800892, 18)
#
# Columns in dataset:
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID']
#
# First 5 rows:
# shape: (5, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Date      ┆ Product   ┆ Sub-produ ┆ Issue     ┆ … ┆ Company   ┆ Timely    ┆ Consumer  ┆ Complain │
# │ received  ┆ ---       ┆ ct        ┆ ---       ┆   ┆ response  ┆ response? ┆ disputed? ┆ t ID     │
# │ ---       ┆ str       ┆ ---       ┆ str       ┆   ┆ to        ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆           ┆ str       ┆           ┆   ┆ consumer  ┆ str       ┆ str       ┆ i64      │
# ...

# %%
df.columns
# Out:
# ['Date received',
#  'Product',
#  'Sub-product',
#  'Issue',
#  'Sub-issue',
#  'Consumer complaint narrative',
#  'Company public response',
#  'Company',
#  'State',
#  'ZIP code',
#  'Tags',
#  'Consumer consent provided?',
#  'Submitted via',
#  'Date sent to company',
#  'Company response to consumer',
#  'Timely response?',
#  'Consumer disputed?',
#  'Complaint ID']

# %%
products = df["Product"].unique().to_list()

# %%
products
# Out:
# ['Money transfer, virtual currency, or money service',
#  'Bank account or service',
#  'Credit reporting',
#  'Vehicle loan or lease',
#  'Credit card or prepaid card',
#  'Checking or savings account',
#  'Consumer Loan',
#  'Debt collection',
#  'Payday loan',
#  'Credit card',
#  'Virtual currency',
#  'Credit reporting or other personal consumer reports',
#  'Prepaid card',
#  'Student loan',
#  'Payday loan, title loan, personal loan, or advance loan',
#  'Credit reporting, credit repair services, or other personal consumer reports',
#  'Money transfers',
#  'Debt or credit management',
#  'Mortgage',
#  'Payday loan, title loan, or personal loan',
#  'Other financial service']
